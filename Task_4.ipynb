# %%
## converting image into grey scale
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('C:\\Users\\mdzai\\Downloads\\Bracelet.jpeg',cv2.IMREAD_GRAYSCALE)
##cv2.imshow('image',img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
plt.imshow(img, cmap='gray',interpolation='bicubic')
# bicubic interpolation is used for smoother appearence of image and cmap is color map
plt.show()

# %%
# showing the image specified
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('C:\\Users\\mdzai\\Downloads\\Bracelet.jpeg',cv2.IMREAD_GRAYSCALE)
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# drawing a line of width 5 onto the grey scale image
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('C:\\Users\\mdzai\\Downloads\\Bracelet.jpeg',cv2.IMREAD_GRAYSCALE)

plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.plot([200,300,400],[100,200,300],'c', linewidth=5)
plt.show()

# %%
##video capture 
import numpy as np
import cv2

cap = cv2.VideoCapture(0)
 
while(True):
    ret, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#     it converts the image into gray scale
 
    cv2.imshow('frame',gray)
#     shows he image through webcam
# to come out of infinite loop we use wait key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
# releases the camera 
cv2.destroyAllWindows()

# %%
# shows both the images (the normal and gray scale) to identify the difference
import numpy as np
import cv2

cap = cv2.VideoCapture(0)
 
while(True):
    ret, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
 
    cv2.imshow('frame',gray)
    cv2.imshow('plain',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
# shows normal image
import numpy as np
import cv2

cap = cv2.VideoCapture(0)
 
while(True):
    ret, frame = cap.read()
    cv2.imshow('plain',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
# converting the video to gray scale
import numpy as np
import cv2

cap = cv2.VideoCapture(0)
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output.avi',fourcc, 20.0, (640,480))

while(True):
    ret, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    
    out.write(frame)
    cv2.imshow('frame',gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()

# %%
# drawingon the image 
import numpy as np
import cv2

img = cv2.imread('C:\\Users\\mdzai\\Downloads\\Bracelet.jpeg',cv2.IMREAD_COLOR)
# drawing a line stating at (0,0)and end at (200,300)and the BGR(blue green red )ratio are(255,255,255) for white
# for black(0,0,0) line width is 50


cv2.line(img,(0,0),(200,300),(255,255,255),50)
cv2.rectangle(img,(500,250),(1000,500),(0,0,255),5)
cv2.circle(img,(447,63), 63, (0,255,0), -1)
# pts are points and np is numpy
pts = np.array([[100,50],[200,300],[700,200],[500,100]], np.int32)
pts = pts.reshape((-1,1,2))
cv2.polylines(img, [pts], True, (0,255,255), 5)
font = cv2.FONT_HERSHEY_SIMPLEX
# image , text to print, starting co-ordinates,font of the letters, font size, color, thickness of letter, aa(anti aliased which gives smoother letters or image)
cv2.putText(img,'Python ',(10,500), font, 6, (200,255,155), 13, cv2.LINE_AA)
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Image opertion
import cv2
import numpy as np

img = cv2.imread('C:\\Users\\mdzai\\Downloads\\Bracelet.jpeg',cv2.IMREAD_COLOR)
# value of pixels actually the color values
px = img[55,55]
# Modifying the pixel to white
img[55,55] = [255,255,255]
px = img[55,55]
print(px)
px = img[100:150,100:150]
print(px)
img[100:150,100:150] = [255,255,255]
print(img.shape)
print(img.size)
print(img.dtype)
watch_face = img[37:111,107:194]
img[0:74,0:87] = watch_face

cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [255 255 255]
# [[[212 213 211]
#   [212 213 211]
#   [212 213 211]
#   ...
#   [218 216 215]
#   [219 217 216]
#   [219 217 216]]
#
#  [[214 215 213]
#   [214 215 213]
#   [215 216 214]
#   ...
#   [220 218 217]
#   [220 218 217]
#   [221 219 218]]
#
#  [[216 217 215]
#   [217 218 216]
#   [217 218 216]
#   ...
#   [221 219 218]
#   [221 219 218]
#   [222 220 219]]
#
#  ...
#
#  [[181 181 181]
#   [180 180 180]
#   [179 179 179]
#   ...
#   [173 172 174]
#   [175 174 176]
#   [175 174 176]]
#
#  [[179 179 179]
#   [178 178 178]
#   [177 177 177]
#   ...
#   [172 171 173]
#   [173 172 174]
#   [174 173 175]]
#
#  [[178 178 178]
#   [176 176 176]
#   [176 176 176]
#   ...
#   [174 173 175]
#   [174 173 175]
#   [174 173 175]]]
# (960, 1280, 3)
# 3686400
# uint8

# %%
# Drawing rectangle on the image
import numpy as np
import cv2

img = cv2.imread('C:\\Users\\mdzai\\Downloads\\Bracelet.jpeg',cv2.IMREAD_COLOR)
# drawing a line stating at (0,0)and end at (200,300)and the BGR(blue green red )ratio are(255,255,255) for white
# for black(0,0,0) line width is 50


cv2.line(img,(0,0),(450,550),(0,0,0),50)
cv2.rectangle(img,(0,90),(300,700),(255,0,0),-1)
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

img = cv2.imread('C:\\Users\\mdzai\\Downloads\\Bracelet.jpeg',cv2.IMREAD_COLOR)
# value of pixels actually the color values
img[55,55]=[255,255,255]
px = img[55,55]
img[100:150,100:150]=[255,255,255]
# region of image
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Actual color value for the pixel

# %%
# Adding two images using inbuilt function
import cv2
import numpy as np

# 500 x 250
img1 = cv2.imread("C:\\Users\\mdzai\\Downloads\\3D-Matplotlib.png")
img2 = cv2.imread("C:\\Users\\mdzai\\Downloads\\mainsvmimage.png")

add = cv2.add(img1, img2)

cv2.imshow('add',add)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Adding images using the arithmetic functions
import cv2
import numpy as np

# 500 x 250
img1 = cv2.imread("C:\\Users\\mdzai\\Downloads\\3D-Matplotlib.png")
img2 = cv2.imread("C:\\Users\\mdzai\\Downloads\\mainsvmimage.png")

add = img1 +img2

cv2.imshow('add',add)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Adding two images using weight
import cv2
import numpy as np

img1 = cv2.imread("C:\\Users\\mdzai\\Downloads\\3D-Matplotlib.png")
img2 = cv2.imread("C:\\Users\\mdzai\\Downloads\\mainsvmimage.png")

weighted = cv2.addWeighted(img1, 0.6, img2, 0.4, 0)
# img one weight is 0.6 or 60%and img 2 weight is 0.4 or 40% gamma is 0
cv2.imshow('weighted',weighted)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# converting the main logo into gray scale i.e removing the colors
import cv2
import numpy as np
img1 = cv2.imread("C:\\Users\\mdzai\\Downloads\\3D-Matplotlib.png")
img2 = cv2.imread("C:\\Users\\mdzai\\Downloads\\mainlogo.png")
rows,cols,channels=img2.shape
roi=img1[0:rows,0:cols]
img2gray=cv2.cvtColor( img2, cv2.COLOR_BGR2GRAY)
ret, mask=cv2.threshold(img2gray, 220, 255, cv2.THRESH_BINARY_INV)
cv2.imshow('mask',mask)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Combining the two images according to the will using gray
import cv2
import numpy as np

# Load two images
img1 = cv2.imread("C:\\Users\\mdzai\\Downloads\\3D-Matplotlib.png")
img2 = cv2.imread("C:\\Users\\mdzai\\Downloads\\mainlogo.png")

# I want to put logo on top-left corner, So I create a ROI
rows,cols,channels = img2.shape
roi = img1[0:rows, 0:cols ]

# Now create a mask of logo and create its inverse mask
img2gray = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)

# add a threshold
ret, mask = cv2.threshold(img2gray, 220, 255, cv2.THRESH_BINARY_INV)

mask_inv = cv2.bitwise_not(mask)

# Now black-out the area of logo in ROI
img1_bg = cv2.bitwise_and(roi,roi,mask = mask_inv)

# Take only region of logo from logo image.
img2_fg = cv2.bitwise_and(img2,img2,mask = mask)

dst = cv2.add(img1_bg,img2_fg)
img1[0:rows, 0:cols ] = dst

cv2.imshow('res',img1)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Normal thresholding
import cv2
import numpy as np

img = cv2.imread("C:\\Users\\mdzai\\Downloads\\bookpage.jpg")
retval, threshold = cv2.threshold(img, 12, 255, cv2.THRESH_BINARY)
# img: This is the input image on which thresholding is applied. It should be a single-channel grayscale image.
# 12: This is the threshold value. Pixels with intensity values less than or equal to this threshold will be set to 0, and pixels with intensity values greater than the threshold will be set to 255.
# 255: This is the maximum value that pixels can be set to. In this case, pixels above the threshold are set to the maximum value, which is 255.
# cv2.THRESH_BINARY: This is the thresholding method used. It indicates that a binary thresholding is applied, meaning pixels are assigned either 0 or the maximum value based on the threshold condition.
cv2.imshow('original',img)
cv2.imshow('threshold',threshold)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# let's grayscale the image, and then do a threshold
import cv2
import numpy as np
img = cv2.imread("C:\\Users\\mdzai\\Downloads\\bookpage.jpg")
grayscaled = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
retval, threshold = cv2.threshold(grayscaled, 10, 255, cv2.THRESH_BINARY)
cv2.imshow('original',img)
cv2.imshow('threshold',threshold)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# this thresholding gives clear image to read
import cv2
import numpy as np
img = cv2.imread("C:\\Users\\mdzai\\Downloads\\bookpage.jpg")


th = cv2.adaptiveThreshold(grayscaled, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 115, 1)
cv2.imshow('original',img)
cv2.imshow('Adaptive threshold',th)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# otsu thresholding
import cv2
import numpy as np
img = cv2.imread("C:\\Users\\mdzai\\Downloads\\bookpage.jpg")
th = cv2.adaptiveThreshold(grayscaled, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 115, 1)
retval2,threshold2 = cv2.threshold(grayscaled,125,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
cv2.imshow('original',img)
cv2.imshow('Otsu threshold',threshold2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# color filtering
import cv2
import numpy as np

cap = cv2.VideoCapture(0)

while(1):
    _, frame = cap.read()
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
    lower_red = np.array([30,150,50])
    upper_red = np.array([255,255,180])
    
    mask = cv2.inRange(hsv, lower_red, upper_red)
    res = cv2.bitwise_and(frame,frame, mask= mask)

    cv2.imshow('frame',frame)
    cv2.imshow('mask',mask)
    cv2.imshow('res',res)
    
    k = cv2.waitKey(5) & 0xFF
#     press escape to end
    if k == 27:
        break

cv2.destroyAllWindows()
cap.release()

# %%
# smoothing and blurring the background noises
import cv2
import numpy as np

cap = cv2.VideoCapture(0)

while(1):

    _, frame = cap.read()
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
    lower_red = np.array([30,150,50])
    upper_red = np.array([255,255,180])
    
    mask = cv2.inRange(hsv, lower_red, upper_red)
    res = cv2.bitwise_and(frame,frame, mask= mask)
    kernel = np.ones((15,15),np.float32)/225
    smoothed = cv2.filter2D(res,-1,kernel)
    blur = cv2.GaussianBlur(res,(15,15),0)
    median = cv2.medianBlur(res,15)
    bilateral = cv2.bilateralFilter(res,15,75,75)
    cv2.imshow('bilateral Blur',bilateral)
    cv2.imshow('Median Blur',median)
    cv2.imshow('Gaussian Blurring',blur)
    cv2.imshow('Original',frame)
    cv2.imshow('Averaging',smoothed)

    k = cv2.waitKey(5) & 0xFF
    if k == 27:
        break

cv2.destroyAllWindows()
cap.release()

# %%
# Morphological transformation
import cv2
import numpy as np

cap = cv2.VideoCapture(0)

while(1):

    _, frame = cap.read()
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
    lower_red = np.array([30,150,50])
    upper_red = np.array([255,255,180])
    
    mask = cv2.inRange(hsv, lower_red, upper_red)
    res = cv2.bitwise_and(frame,frame, mask= mask)

    kernel = np.ones((5,5),np.uint8)
    erosion = cv2.erode(mask,kernel,iterations = 1)
    dilation = cv2.dilate(mask,kernel,iterations = 1)

    cv2.imshow('Original',frame)
    cv2.imshow('Mask',mask)
    cv2.imshow('Erosion',erosion)
    cv2.imshow('Dilation',dilation)

    k = cv2.waitKey(5) & 0xFF
    if k == 27:
        break

cv2.destroyAllWindows()
cap.release()

# %%
# Morphological transformation
import cv2
import numpy as np

cap = cv2.VideoCapture(0)

while(1):

    _, frame = cap.read()
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
    lower_red = np.array([30,150,50])
    upper_red = np.array([255,255,180])
    
    mask = cv2.inRange(hsv, lower_red, upper_red)
    res = cv2.bitwise_and(frame,frame, mask= mask)

    kernel = np.ones((5,5),np.uint8)
    opening = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)
    closing = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
    
    cv2.imshow('Original',frame)
    cv2.imshow('Mask',mask)
    cv2.imshow('Opening',opening)
    cv2.imshow('Closing',closing)

    k = cv2.waitKey(5) & 0xFF
    if k == 27:
        break

cv2.destroyAllWindows()
cap.release()
# It is the difference between input image and Opening of the image
#     cv2.imshow('Tophat',tophat)
 # It is the difference between the closing of the input image and input image.
#     cv2.imshow('Blackhat',blackhat)

# %%
# gradients
import cv2
import numpy as np

cap = cv2.VideoCapture(0)

while(1):

    _, frame = cap.read()
    laplacian=cv2.Laplacian(frame,cv2.CV_64F)
    
    cv2.imshow('Original',frame)
    cv2.imshow('laplacian',laplacian)
    
    k = cv2.waitKey(5) & 0xFF
    if k == 27:
        break

cv2.destroyAllWindows()
cap.release()

# %%
# gradients
import cv2
import numpy as np

cap = cv2.VideoCapture(0)

while(1):

    # Take each frame
    _, frame = cap.read()
    laplacian = cv2.Laplacian(frame,cv2.CV_64F)
    sobelx = cv2.Sobel(frame,cv2.CV_64F,1,0,ksize=5)
    sobely = cv2.Sobel(frame,cv2.CV_64F,0,1,ksize=5)

    cv2.imshow('Original',frame)
  
    cv2.imshow('laplacian',laplacian)
    cv2.imshow('sobelx',sobelx)
    cv2.imshow('sobely',sobely)

    k = cv2.waitKey(5) & 0xFF
    if k == 27:
        break

cv2.destroyAllWindows()
cap.release()

# %%
# Edge detection
import cv2
import numpy as np

cap = cv2.VideoCapture(0)

while(1):

    _, frame = cap.read()
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
    lower_red = np.array([30,150,50])
    upper_red = np.array([255,255,180])
    
    mask = cv2.inRange(hsv, lower_red, upper_red)
    res = cv2.bitwise_and(frame,frame, mask= mask)

    cv2.imshow('Original',frame)
    edges = cv2.Canny(frame,100,200)
    cv2.imshow('Edges',edges)

    k = cv2.waitKey(5) & 0xFF
    if k == 27:
        break

cv2.destroyAllWindows()
cap.release()

# %%
# Template matching
import cv2
import numpy as np

img_rgb = cv2.imread("C:\\Users\\mdzai\\Downloads\\opencv-template-matching-python-tutorial (1).jpg")
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)

template = cv2.imread("C:\\Users\\mdzai\\Downloads\\opencv-template-for-matching (1).jpg",0)
w, h = template.shape[::-1]
res = cv2.matchTemplate(img_gray,template,cv2.TM_CCOEFF_NORMED)
threshold = 0.7
loc = np.where( res >= threshold)
for pt in zip(*loc[::-1]):
    cv2.rectangle(img_rgb, pt, (pt[0] + w, pt[1] + h), (0,255,255), 2)

cv2.imshow('Detected',img_rgb)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# foreground extraction
import numpy as np
import cv2
from matplotlib import pyplot as plt

img = cv2.imread("C:\\Users\\mdzai\\Downloads\\opencv-python-foreground-extraction-tutorial.jpg")
mask = np.zeros(img.shape[:2],np.uint8)

bgdModel = np.zeros((1,65),np.float64)
fgdModel = np.zeros((1,65),np.float64)

rect = (161,79,150,150)
cv2.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv2.GC_INIT_WITH_RECT)
mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
img = img*mask2[:,:,np.newaxis]

plt.imshow(img)
plt.colorbar()
plt.show()

# %%
# Corner detection
import numpy as np
import cv2

img = cv2.imread("C:\\Users\\mdzai\\Downloads\\opencv-corner-detection-sample.jpg")
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray = np.float32(gray)

corners = cv2.goodFeaturesToTrack(gray, 100, 0.01, 10)
corners = np.int0(corners)
for corner in corners:
    x,y = corner.ravel()
    cv2.circle(img,(x,y),3,255,-1)
    
cv2.imshow('Corner',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Brute force
import matplotlib.pyplot as plt

img1 = cv2.imread("C:\\Users\\mdzai\\Downloads\\opencv-feature-matching-template.jpg",0)
# 1 for good qualityt or colored image
img2 = cv2.imread("C:\\Users\\mdzai\\Downloads\\opencv-feature-matching-image.jpg",0)
orb = cv2.ORB_create()
kp1, des1 = orb.detectAndCompute(img1,None)
kp2, des2 = orb.detectAndCompute(img2,None)
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
matches = bf.match(des1,des2)
matches = sorted(matches, key = lambda x:x.distance)
img3 = cv2.drawMatches(img1,kp1,img2,kp2,matches[:10],None, flags=2)
plt.imshow(img3)
plt.show()

# %%
# Mog background reduction
import numpy as np
import cv2

cap = cv2.VideoCapture("C:\\Users\\mdzai\\Downloads\\people-walking.mp4")
fgbg = cv2.createBackgroundSubtractorMOG2()

while(1):
    ret, frame = cap.read()

    fgmask = fgbg.apply(frame)
 
    cv2.imshow('fgmask',frame)
    cv2.imshow('frame',fgmask)

    
    k = cv2.waitKey(30) & 0xff
    if k == 27:
        break
    

cap.release()
cv2.destroyAllWindows()

# %%
# MOG
import numpy as np
import cv2

cap = cv2.VideoCapture(0)
fgbg = cv2.createBackgroundSubtractorMOG2()

while(1):
    ret, frame = cap.read()

    fgmask = fgbg.apply(frame)
 
    cv2.imshow('fgmask',frame)
    cv2.imshow('frame',fgmask)

    
    k = cv2.waitKey(30) & 0xff
    if k == 27:
        break
    

cap.release()
cv2.destroyAllWindows()

# %%
# Face and eye detection
import numpy as np 
import cv2 
# multiple cascades: https://github.com/Itseez/opencv/tree/master/data/haarcascades
#https://github.com/Itseez/opencv/blob/master/data/haarcascades/haarcascade_frontalface_default.xml 
face_cascade = cv2.CascadeClassifier("C:\\Users\\mdzai\\anaconda3\\Lib\\site-packages\\cv2\\data\\haarcascade_frontalface_default.xml") 
#https://github.com/Itseez/opencv/blob/master/data/haarcascades/haarcascade_eye.xml 
eye_cascade = cv2.CascadeClassifier("C:\\Users\\mdzai\\anaconda3\\Lib\\site-packages\\cv2\\data\\haarcascade_eye.xml") 
cap = cv2.VideoCapture(0) 
while 1: 
    ret, img = cap.read()
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces: 
        cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
        roi_gray = gray[y:y+h, x:x+w] 
        roi_color = img[y:y+h, x:x+w] 
        eyes = eye_cascade.detectMultiScale(roi_gray)
        for (ex,ey,ew,eh) in eyes: 
            cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
    cv2.imshow('img',img) 
    k = cv2.waitKey(30) & 0xff 
    if k == 27: 
        break 
cap.release() 
cv2.destroyAllWindows()

# %%
# Creating own haarcascade code
import cv2
cap=cv2.VideoCapture(0)
face_cascade = cv2.CascadeClassifier("C:\\Users\\mdzai\\Downloads\\custom haar cascade\\classifier\\Pineaple.xml")
while(True):
    ret,frame=cap.read()
    gray=cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces=face_cascade.detectMultiScale(gray,1.3,5)
    for (x,y,w,h) in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),2)
    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xFF==('q'):
        break
cap.release()
cv2.destroyAllWindows()
